# %% [markdown]
# Start with imports

# %%
import pandas as pd

# %% [markdown]
# Basic view of BALANCE csv

# %%
df = pd.read_csv('/Users/robinkurosawa/git/electricity-demand-forecasting/data/raw/EIA930_BALANCE_2023_Jul_Dec.csv')

df.head()
# Out:
#   Balancing Authority   Data Date  Hour Number Local Time at End of Hour  \
# 0                AECI  07/01/2023            1     07/01/2023 1:00:00 AM
# 1                AECI  07/01/2023            2     07/01/2023 2:00:00 AM
# 2                AECI  07/01/2023            3     07/01/2023 3:00:00 AM
# 3                AECI  07/01/2023            4     07/01/2023 4:00:00 AM
# 4                AECI  07/01/2023            5     07/01/2023 5:00:00 AM
#
#   UTC Time at End of Hour  Demand Forecast (MW)  Demand (MW)  \
# 0   07/01/2023 6:00:00 AM                3074.0       3102.0
# 1   07/01/2023 7:00:00 AM                2866.0       2902.0
# 2   07/01/2023 8:00:00 AM                2702.0       2771.0
# 3   07/01/2023 9:00:00 AM                2597.0       2654.0
# 4  07/01/2023 10:00:00 AM                2506.0       2542.0
#
#    Net Generation (MW)  Total Interchange (MW)  Sum(Valid DIBAs) (MW)  ...  \
# 0               2314.0                  -788.0                 -788.0  ...
# ...

# %%
df["Balancing Authority"].value_counts()
# Out:
# Balancing Authority
# MISO    4368
# DEAA    4368
# LGEE    4368
# PNM     4368
# HGMA    4368
#         ...
# ISNE    4367
# JEA     4367
# LDWP    4367
# AVA     4367
# YAD     4367
# Name: count, Length: 61, dtype: int64

# %%
df = df[df['Balancing Authority'] == 'ISNE']

df
# Out:
#        Balancing Authority   Data Date  Hour Number Local Time at End of Hour  \
# 117790                ISNE  07/01/2023            1     07/01/2023 1:00:00 AM
# 117791                ISNE  07/01/2023            2     07/01/2023 2:00:00 AM
# 117792                ISNE  07/01/2023            3     07/01/2023 3:00:00 AM
# 117793                ISNE  07/01/2023            4     07/01/2023 4:00:00 AM
# 117794                ISNE  07/01/2023            5     07/01/2023 5:00:00 AM
# ...                    ...         ...          ...                       ...
# 122202                ISNE  12/31/2023           20     12/31/2023 8:00:00 PM
# 122203                ISNE  12/31/2023           21     12/31/2023 9:00:00 PM
# 122204                ISNE  12/31/2023           22    12/31/2023 10:00:00 PM
# 122205                ISNE  12/31/2023           23    12/31/2023 11:00:00 PM
# 122206                ISNE  12/31/2023           24    01/01/2024 12:00:00 AM
#
# ...

# %%
df[df['Data Date'] == '12/30/2023']
# Out:
#        Balancing Authority   Data Date  Hour Number Local Time at End of Hour  \
# 122159                ISNE  12/30/2023            1     12/30/2023 1:00:00 AM
# 122160                ISNE  12/30/2023            2     12/30/2023 2:00:00 AM
# 122161                ISNE  12/30/2023            3     12/30/2023 3:00:00 AM
# 122162                ISNE  12/30/2023            4     12/30/2023 4:00:00 AM
# 122163                ISNE  12/30/2023            5     12/30/2023 5:00:00 AM
# 122164                ISNE  12/30/2023            6     12/30/2023 6:00:00 AM
# 122165                ISNE  12/30/2023            7     12/30/2023 7:00:00 AM
# 122166                ISNE  12/30/2023            8     12/30/2023 8:00:00 AM
# 122167                ISNE  12/30/2023            9     12/30/2023 9:00:00 AM
# 122168                ISNE  12/30/2023           10    12/30/2023 10:00:00 AM
# 122169                ISNE  12/30/2023           11    12/30/2023 11:00:00 AM
# ...
